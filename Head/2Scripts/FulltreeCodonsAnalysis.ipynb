# %% [markdown]
# # Analysis of fulltree table with ancestral and derived codons

# %% [markdown]
# Import the data from Body and convert it into a pandas dataframe:

# %%
import pandas as pd
data = pd.read_csv("../../Body/3Results/fulltreeCodons.csv", sep=";")

# %% [markdown]
# Let's take a look at the table:

# %%
data
# Out:
#         first      second  position  ref_pos ancestor descendant  \
# 0       28409  AM_PR_0048       174      150    ttTc-      ttCc-
# 1       28409  AM_PR_0048       593      522    acTc-      acAc-
# 2       28409  AM_PR_0048      5007     4840    ctAac      ctGac
# 3       28409  AM_PR_0048      7971     7774    ccGtc      ccRtc
# 4       28409  AM_PR_0048      8017     7820    ccCat      ccMat
# ...       ...         ...       ...      ...      ...        ...
# 577271  27068  EU_DK_0660     12579    12339    taGcc      taAcc
# 577272  27068  EU_DK_0660     12597    12357    taGcc      taAcc
# 577273  27068  EU_DK_0660     13191    12949    aaGcg      aaAcg
# 577274  27068  EU_DK_0660     15612    15366    aaCcc      aaTcc
# 577275  27068  EU_DK_0660     16588    16303    agCac      agTac
#
#        nuc_ref_in_ali  gene_info  gene_start  pos_in_codon      synonymous  \
# 0                   C   D-loop_2         NaN           NaN             NaN
# ...

# %%
# 0. First check dataset for disrepancies (на вшивость) 

# ANALYSIS

# 1. Simple summary descriptive statistics
# How many different positions in codon

# 2. Where along the genome
# histogram on genome + 2000 genomes article
# Which genes
# are they correlated (Spearman rank and scatterplot )

# 2. Loss of function or gain of function?
# How many stop codons or not?
# How many to stop or from stop

# 3. Which aa to which
# in which biochem group using matrices Grantham distance
# How many ambiguous
